# %%
import numpy as np
import os
import xarray as xr
import glob
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as mcolors
import dask.array as da
import pickle
from scipy.stats import t
import matplotlib.ticker as ticker
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.cm as cm

# %% [markdown]
# ### purpose is to explore what humidity, and wind profiles look like across the day for wet and dry apes, discern differences

# %%
# removes underground values, contains advections and mean wind profiles

with open('/home/annierosen16/master_clean.pkl', 'rb') as f:
    
    master = pickle.load(f)

# %%
# reading in ERA5 u, v, w and q

base_path = '/data/rong4/Data/ERA5/3hourly/quvw_US'

years = [str(year) for year in range(2001, 2019)]

def get_files(folder, component):

    files = glob.glob(os.path.join(base_path, folder, f"era5.{component}.*.nc"))

    filtered_files = [f for f in files if any(year in f for year in years)]
    
    return filtered_files

# Get the files for each component

u_files = get_files('u_component_of_wind', 'u_component_of_wind')

v_files = get_files('v_component_of_wind', 'v_component_of_wind')

w_files = get_files('vertical_velocity', 'vertical_velocity')

q_files = get_files('specific_humidity', 'specific_humidity')

all_files = u_files + v_files + q_files + w_files

# open all datasets at once

uvwq = xr.open_mfdataset(all_files, combine='by_coords', chunks={'time': 24})

# %%
uvwq_sgp = uvwq.sel(
    
    latitude=slice(39, 30),
    
    longitude=slice(-105, -95)
)

uvwq_sgp['time'] = uvwq_sgp['time'] - pd.Timedelta(hours=6)

uvwq_sgp = uvwq_sgp.where(
    
    (uvwq_sgp.time.dt.month.isin([5, 6, 7, 8, 9])) &
    
    (uvwq_sgp.time.dt.year.isin(range(2001, 2019))),
    
    drop=True
)

uvwq_sgp["w"] = uvwq_sgp["w"] * -1

# %% [markdown]
# #### what does vertical velocity look like at every hour of the day on average across the domain?

# %%
# Step 1: Select 800 hPa level
ds = uvwq_sgp.sel(level=800)

# Step 2: Extract hour from time dimension
ds['hour'] = ds['time'].dt.hour  

# Step 3: Group by hour and compute the mean vertical velocity
w_hourly_mean = ds['w'].groupby(ds['hour']).mean(dim='time')

available_hours = sorted(w_hourly_mean['hour'].values)

# **Step 5: Coarsen by Selecting Every 4th Point**

w_hourly_mean = w_hourly_mean.isel(latitude=slice(None, None, 4), longitude=slice(None, None, 4))

w_hourly_mean = w_hourly_mean.load()

print("loaded")
# Out:
# loaded

# %%
# Use coarsened lat/lon

ds = w_hourly_mean

lons = ds['longitude']

lats = ds['latitude']

# Set up subplots
n_hours = len(available_hours)

n_cols = 2  

n_rows = 4  

fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, 10), subplot_kw={'projection': ccrs.PlateCarree()})
axes = axes.flatten()

# Create a placeholder for colorbar data
pcm = None  

for i, hour in enumerate(available_hours):  
    
    ax = axes[i]
    
    # Select the mean w values for this hour
    w_data = w_hourly_mean.sel(hour=hour).values  # Convert to NumPy for speed

    # **Use rasterized=True for faster rendering**
    pcm = ax.pcolormesh(lons, lats, w_data, cmap='coolwarm_r', shading='nearest', rasterized=True, transform=ccrs.PlateCarree())

    # Add map features
    ax.add_feature(cfeature.COASTLINE, linewidth=0.8)
    
    ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.6)
    
    ax.add_feature(cfeature.STATES, linestyle='--', linewidth=0.6, edgecolor="black")

    # Title for each subplot
    ax.set_title(f"Hour {hour:02d}", fontsize=10)

# Adjust layout to create space for the colorbar
fig.subplots_adjust(bottom=0.1, top=0.95, left=0.05, right=0.85, wspace=0.3, hspace=0.3)

# **Step 6: Add colorbar in an external axis to prevent overlap**
cbar_ax = fig.add_axes([0.88, 0.2, 0.02, 0.6])  # Defines colorbar size & position

cbar = fig.colorbar(pcm, cax=cbar_ax)

cbar.set_label("Mean Vertical Motion (w) [Pa/s]")

# Show the final plot
plt.show()

# %% [markdown]
# #### separating by hour of the day

# %%
_0lst = uvwq_sgp.sel(time=uvwq_sgp.time.dt.hour == 0)

_3lst = uvwq_sgp.sel(time=uvwq_sgp.time.dt.hour == 3)

_6lst = uvwq_sgp.sel(time=uvwq_sgp.time.dt.hour == 6)

_9lst = uvwq_sgp.sel(time=uvwq_sgp.time.dt.hour == 9)

_12lst = uvwq_sgp.sel(time=uvwq_sgp.time.dt.hour == 12)

_15lst = uvwq_sgp.sel(time=uvwq_sgp.time.dt.hour == 15)

_18lst = uvwq_sgp.sel(time=uvwq_sgp.time.dt.hour == 18)

_21lst = uvwq_sgp.sel(time=uvwq_sgp.time.dt.hour == 21)

# %% [markdown]
# #### defining dry apes and wet apes with surface pressure in order to account for topography in composites

# %%
dryapes = master[master['dryape']==True][['date','latitude','longitude', 'average_sp']]

wetapes = master[master['wetape']==True][['date','latitude','longitude','average_sp']]

# %% [markdown]
# #### dryapes vertical velocity composites for all times of day

# %%
pressure_levels = _0lst['level'].data * 100 

xr_all_times = {
    
    "0lst": _0lst, "3lst": _3lst, "6lst": _6lst, "9lst": _9lst,
    
    "12lst": _12lst, "15lst": _15lst, "18lst": _18lst, "21lst": _21lst
}

dryapes['date'] = pd.to_datetime(dryapes['date'])

composite_profiles = {}

for time_label, ds in xr_all_times.items():
    
    w_profiles = ds.sel(
        
        time=xr.DataArray(dryapes['date'].values, dims="points"),
        
        latitude=xr.DataArray(dryapes['latitude'].values, dims="points"),
        
        longitude=xr.DataArray(dryapes['longitude'].values, dims="points"),
        
        method="nearest"
    
    )['w']
    
    sp_expanded = np.expand_dims(dryapes['average_sp'].values, axis=1)  # Shape (n_cases, 1)

    w_profiles_masked = w_profiles.where(pressure_levels < sp_expanded)

    w_profiles_np = w_profiles_masked.values  # Shape: (n_cases, vertical_levels)

    # Compute the mean profile (averaged over all cases)
    
    composite_profiles[time_label] = np.nanmean(w_profiles_np, axis=0)
    
    print(time_label, "complete")

w_dryapes_all_times = pd.DataFrame(composite_profiles)
# Out:
# 0lst complete
# 3lst complete
# 6lst complete
# 9lst complete
# 12lst complete
# 15lst complete
# 18lst complete
# 21lst complete

# %% [markdown]
# #### wetapes vertical velocity composites for all times of day

# %%
pressure_levels = _0lst['level'].data * 100 

xr_all_times = {
    
    "0lst": _0lst, "3lst": _3lst, "6lst": _6lst, "9lst": _9lst,
    
    "12lst": _12lst, "15lst": _15lst, "18lst": _18lst, "21lst": _21lst
}

wetapes['date'] = pd.to_datetime(wetapes['date'])

composite_profiles = {}

for time_label, ds in xr_all_times.items():
    
    w_profiles = ds.sel(
        
        time=xr.DataArray(wetapes['date'].values, dims="points"),
        
        latitude=xr.DataArray(wetapes['latitude'].values, dims="points"),
        
        longitude=xr.DataArray(wetapes['longitude'].values, dims="points"),
        
        method="nearest"
    
    )['w']
    
    sp_expanded = np.expand_dims(wetapes['average_sp'].values, axis=1)  # Shape (n_cases, 1)

    w_profiles_masked = w_profiles.where(pressure_levels < sp_expanded)

    w_profiles_np = w_profiles_masked.values  # Shape: (n_cases, vertical_levels)

    # Compute the mean profile (averaged over all cases)
    
    composite_profiles[time_label] = np.nanmean(w_profiles_np, axis=0)
    
    print(time_label, "complete")

w_wetapes_all_times = pd.DataFrame(composite_profiles)
# Out:
# 0lst complete
# 3lst complete
# 6lst complete
# 9lst complete
# 12lst complete
# 15lst complete
# 18lst complete
# 21lst complete

# %% [markdown]
# #### plots of vertical velocity for dry and wet apes

# %%
pressure = _0lst['level'].data  # Assuming this is consistent for both dry and wet cases

profile_columns = [col for col in w_dryapes_all_times.columns]

dry_color = "#4169E1"  # Royal Blue
wet_color = "#FF8C00"  # Dark Orange

num_profiles = len(profile_columns)

rows = 2
cols = min(4, num_profiles)  # Ensures no extra empty columns

fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 7), sharey=True)
axes = np.ravel(axes)  # Flatten in case of 2D array

# Define pressure levels to shade
shade_min = 800  # hPa

shade_max = 600  # hPa

# Loop through each column (each time of day) and plot dry and wet profiles
for i, (ax, col) in enumerate(zip(axes, profile_columns)):
    
    # Plot the dry and wet profiles
    ax.plot(w_dryapes_all_times[col] / 100, pressure, label=f'Dry APEs', color=dry_color, linewidth=3)
    ax.plot(w_wetapes_all_times[col] / 100, pressure, label=f'Wet APEs', color=wet_color, linewidth=3)
    
    # Shade the 800-600 hPa region
    ax.fill_betweenx(pressure, -0.0008, 0.0008, 
                     where=(pressure <= shade_min) & (pressure >= shade_max), 
                     color='gray', alpha=0.3)
    
    ax.invert_yaxis()  # Invert for atmospheric convention
    
    ax.set_xlim(-0.0008, 0.0008)  # Set x-axis limits
    
    ax.set_title(f'{col} Profile', fontsize=22)  # Title with hour label
    
    ax.set_xlabel('-w (-hPa/s)', fontsize=18)  # x-label
    
    ax.tick_params(axis='both', which='major', labelsize=18)  # Tick label size
    
    ax.axvline(x=0, color='black', linestyle='--', linewidth=1.5)  # Zero reference line
    
    ax.grid(True)
    
    # Add legend only to the first subplot
    if i == 0:
        ax.legend(fontsize=16, loc='best')

plt.tight_layout()

plt.gca().invert_yaxis()

plt.show()

# %% [markdown]
# #### dryapes specific humidity composites for all times of day

# %%
pressure_levels = _0lst['level'].data * 100 

xr_all_times = {
    
    "0lst": _0lst, "3lst": _3lst, "6lst": _6lst, "9lst": _9lst,
    
    "12lst": _12lst, "15lst": _15lst, "18lst": _18lst, "21lst": _21lst
}

dryapes['date'] = pd.to_datetime(dryapes['date'])

composite_profiles = {}

for time_label, ds in xr_all_times.items():
    
    q_profiles = ds.sel(
        
        time=xr.DataArray(dryapes['date'].values, dims="points"),
        
        latitude=xr.DataArray(dryapes['latitude'].values, dims="points"),
        
        longitude=xr.DataArray(dryapes['longitude'].values, dims="points"),
        
        method="nearest"
    
    )['q']
    
    sp_expanded = np.expand_dims(dryapes['average_sp'].values, axis=1)  # Shape (n_cases, 1)

    q_profiles_masked = q_profiles.where(pressure_levels < sp_expanded)

    q_profiles_np = q_profiles_masked.values  # Shape: (n_cases, vertical_levels)

    # Compute the mean profile (averaged over all cases)
    
    composite_profiles[time_label] = np.nanmean(q_profiles_np, axis=0)
    
    print(time_label, "complete")

q_dryapes_all_times = pd.DataFrame(composite_profiles)
# Out:
# 0lst complete
# 3lst complete
# 6lst complete
# 9lst complete
# 12lst complete
# 15lst complete
# 18lst complete

# %% [markdown]
# #### wetapes specific humidity composites for all times of day

# %%
pressure_levels = _0lst['level'].data * 100 

xr_all_times = {
    
    "0lst": _0lst, "3lst": _3lst, "6lst": _6lst, "9lst": _9lst,
    
    "12lst": _12lst, "15lst": _15lst, "18lst": _18lst, "21lst": _21lst
}

wetapes['date'] = pd.to_datetime(wetapes['date'])

composite_profiles = {}

for time_label, ds in xr_all_times.items():
    
    q_profiles = ds.sel(
        
        time=xr.DataArray(wetapes['date'].values, dims="points"),
        
        latitude=xr.DataArray(wetapes['latitude'].values, dims="points"),
        
        longitude=xr.DataArray(wetapes['longitude'].values, dims="points"),
        
        method="nearest"
    
    )['q']
    
    sp_expanded = np.expand_dims(wetapes['average_sp'].values, axis=1)  # Shape (n_cases, 1)

    q_profiles_masked = q_profiles.where(pressure_levels < sp_expanded)

    q_profiles_np = q_profiles_masked.values  # Shape: (n_cases, vertical_levels)

    # Compute the mean profile (averaged over all cases)
    
    composite_profiles[time_label] = np.nanmean(q_profiles_np, axis=0)
    
    print(time_label, "complete")

q_wetapes_all_times = pd.DataFrame(composite_profiles)
# Out:
# 0lst complete
# 3lst complete
# 6lst complete
# 9lst complete
# 12lst complete
# 15lst complete
# 18lst complete
# 21lst complete

# %% [markdown]
# #### composite q profiles plotted

# %%
q_wetapes_all_times_gkg = q_wetapes_all_times * 1000

q_dryapes_all_times_gkg = q_dryapes_all_times * 1000

pressure = _0lst['level'].data  # Assuming this is consistent for both dry and wet cases

profile_columns = [col for col in q_dryapes_all_times.columns]

dry_color = "#4169E1"  # Royal Blue
wet_color = "#FF8C00"  # Dark Orange

num_profiles = len(profile_columns)

rows = 2
cols = min(4, num_profiles)  # Ensures no extra empty columns

fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 7), sharey=True)
axes = np.ravel(axes)  # Flatten in case of 2D array

# Define pressure levels to shade
shade_min = 800  # hPa

shade_max = 600  # hPa

# Loop through each column (each time of day) and plot dry and wet profiles
for i, (ax, col) in enumerate(zip(axes, profile_columns)):
    
    # Plot the dry and wet profiles
    ax.plot(q_dryapes_all_times_gkg[col] , pressure, label=f'Dry APEs', color=dry_color, linewidth=3)
    ax.plot(q_wetapes_all_times_gkg[col] , pressure, label=f'Wet APEs', color=wet_color, linewidth=3)
    
    # Shade the 800-600 hPa region
    ax.fill_betweenx(pressure, 0, 18, 
                     where=(pressure <= shade_min) & (pressure >= shade_max), 
                     color='gray', alpha=0.3)
    
    ax.invert_yaxis()  # Invert for atmospheric convention
    
    ax.set_xlim(0, 18)  # Set x-axis limits
    
    ax.set_title(f'{col} Profile', fontsize=22)  # Title with hour label
    
    ax.set_xlabel('q (g/kg)', fontsize=18)  # x-label
    
    ax.tick_params(axis='both', which='major', labelsize=18)  # Tick label size
    
    ax.axvline(x=0, color='black', linestyle='--', linewidth=1.5)  # Zero reference line
    
    ax.grid(True)
    
    # Add legend only to the first subplot
    if i == 0:
        ax.legend(fontsize=16, loc='best')

plt.tight_layout()

plt.gca().invert_yaxis()

plt.show()

# %%
# Convert specific humidity to g/kg
q_wetapes_all_times_gkg = q_wetapes_all_times * 1000

q_dryapes_all_times_gkg = q_dryapes_all_times * 1000

pressure = _0lst['level'].data  # Assuming this is consistent for both dry and wet cases

# Define new time groups

time_groups = {
    "0-3 LST": ["0lst", "3lst"],
    "6-9 LST": ["6lst", "9lst"],
    "12-15 LST": ["12lst", "15lst"],
    "18-21 LST": ["18lst", "21lst"]
}

# Compute mean specific humidity for each group
q_dry_grouped = {label: q_dryapes_all_times_gkg[cols].mean(axis=1) for label, cols in time_groups.items()}

q_wet_grouped = {label: q_wetapes_all_times_gkg[cols].mean(axis=1) for label, cols in time_groups.items()}

# Generate distinct colors for different groups
colors = cm.coolwarm_r(np.linspace(0, 1, len(time_groups)))

# Create side-by-side subplots
fig, axes = plt.subplots(1, 2, figsize=(8, 6), sharey=True)

# --- Dry APEs Figure ---
ax_dry = axes[0]

for (label, q_profile), color in zip(q_dry_grouped.items(), colors):
    ax_dry.plot(q_profile, pressure, label=label, color=color, linewidth=1.5)

# Shade the 800-600 hPa region
shade_min, shade_max = 800, 600

# ax_dry.fill_betweenx(pressure, 0, 18, where=(pressure <= shade_min) & (pressure >= shade_max), 
#                       color='gray', alpha=0.3)

ax_dry.invert_yaxis()  # Invert for atmospheric convention

ax_dry.set_xlim(3, 9)  # Set x-axis limits

ax_dry.set_title('Dry APEs', fontsize=18)

ax_dry.set_xlabel('q (g/kg)', fontsize=16)

ax_dry.set_ylabel('Pressure (hPa)', fontsize=16)

ax_dry.tick_params(axis='both', which='major', labelsize=14)

ax_dry.axvline(x=0, color='black', linestyle='--', linewidth=1)  # Zero reference line

ax_dry.grid(True)

# Add legend
ax_dry.legend(fontsize=12, loc='best')

# --- Wet APEs Figure ---
ax_wet = axes[1]
for (label, q_profile), color in zip(q_wet_grouped.items(), colors):
    ax_wet.plot(q_profile, pressure, label=label, color=color, linewidth=1.5)

# Shade the 800-600 hPa region
# ax_wet.fill_betweenx(pressure, 0, 18, where=(pressure <= shade_min) & (pressure >= shade_max), 
#                       color='gray', alpha=0.3)

ax_wet.invert_yaxis()  # Invert for atmospheric convention

ax_wet.set_xlim(3, 9)  # Set x-axis limits

ax_wet.set_title('Wet APEs', fontsize=18)

ax_wet.set_xlabel('q (g/kg)', fontsize=16)

ax_wet.tick_params(axis='both', which='major', labelsize=14)

ax_wet.axvline(x=0, color='black', linestyle='--', linewidth=1)  # Zero reference line

ax_wet.grid(True)

# Add legend

ax_wet.legend(fontsize=12, loc='best')

plt.tight_layout()

plt.gca().invert_yaxis()

plt.ylim(800, 600)

plt.xlim(3, 9)

plt.show()

# %%
# Convert specific humidity to g/kg
q_wetapes_all_times_gkg = q_wetapes_all_times * 1000

q_dryapes_all_times_gkg = q_dryapes_all_times * 1000

pressure = _0lst['level'].data  # Assuming this is consistent for both dry and wet cases

# Define new time groups

time_groups = {
    "0-3 LST": ["0lst", "3lst"],
    "6-9 LST": ["6lst", "9lst"],
    "12-15 LST": ["12lst", "15lst"],
    "18-21 LST": ["18lst", "21lst"]
}

# Compute mean specific humidity for each group
q_dry_grouped = {label: q_dryapes_all_times_gkg[cols].mean(axis=1) for label, cols in time_groups.items()}

q_wet_grouped = {label: q_wetapes_all_times_gkg[cols].mean(axis=1) for label, cols in time_groups.items()}

# Generate distinct colors for different groups
colors = cm.coolwarm_r(np.linspace(0, 1, len(time_groups)))

# Create side-by-side subplots
fig, axes = plt.subplots(1, 2, figsize=(8, 6), sharey=True)

# --- Dry APEs Figure ---
ax_dry = axes[0]

for (label, q_profile), color in zip(q_dry_grouped.items(), colors):
    ax_dry.plot(q_profile, pressure, label=label, color=color, linewidth=1.5)

# Shade the 800-600 hPa region
shade_min, shade_max = 800, 600

# ax_dry.fill_betweenx(pressure, 0, 18, where=(pressure <= shade_min) & (pressure >= shade_max), 
#                       color='gray', alpha=0.3)

ax_dry.invert_yaxis()  # Invert for atmospheric convention

ax_dry.set_xlim(8, 17)  # Set x-axis limits

ax_dry.set_title('Dry APEs', fontsize=18)

ax_dry.set_xlabel('q (g/kg)', fontsize=16)

ax_dry.set_ylabel('Pressure (hPa)', fontsize=16)

ax_dry.tick_params(axis='both', which='major', labelsize=14)

ax_dry.axvline(x=0, color='black', linestyle='--', linewidth=1)  # Zero reference line

ax_dry.grid(True)

# Add legend
ax_dry.legend(fontsize=12, loc='best')

# --- Wet APEs Figure ---
ax_wet = axes[1]
for (label, q_profile), color in zip(q_wet_grouped.items(), colors):
    ax_wet.plot(q_profile, pressure, label=label, color=color, linewidth=1.5)

# Shade the 800-600 hPa region
# ax_wet.fill_betweenx(pressure, 0, 18, where=(pressure <= shade_min) & (pressure >= shade_max), 
#                       color='gray', alpha=0.3)

ax_wet.invert_yaxis()  # Invert for atmospheric convention

ax_wet.set_xlim(8, 17)  # Set x-axis limits

ax_wet.set_title('Wet APEs', fontsize=18)

ax_wet.set_xlabel('q (g/kg)', fontsize=16)

ax_wet.tick_params(axis='both', which='major', labelsize=14)

ax_wet.axvline(x=0, color='black', linestyle='--', linewidth=1)  # Zero reference line

ax_wet.grid(True)

# Add legend

ax_wet.legend(fontsize=12, loc='best')

plt.tight_layout()

plt.gca().invert_yaxis()

plt.ylim(1000, 800)

# plt.xlim(2, 10)

plt.show()

# %% [markdown]
# #### dry apes meridional wind speed

# %%
pressure_levels = _0lst['level'].data * 100 

xr_all_times = {
    
    "0lst": _0lst, "3lst": _3lst, "6lst": _6lst, "9lst": _9lst,
    
    "12lst": _12lst, "15lst": _15lst, "18lst": _18lst, "21lst": _21lst
}

dryapes['date'] = pd.to_datetime(dryapes['date'])

composite_profiles = {}

for time_label, ds in xr_all_times.items():
    
    v_profiles = ds.sel(
        
        time=xr.DataArray(dryapes['date'].values, dims="points"),
        
        latitude=xr.DataArray(dryapes['latitude'].values, dims="points"),
        
        longitude=xr.DataArray(dryapes['longitude'].values, dims="points"),
        
        method="nearest"
    
    )['v']
    
    sp_expanded = np.expand_dims(dryapes['average_sp'].values, axis=1)  # Shape (n_cases, 1)

    v_profiles_masked = v_profiles.where(pressure_levels < sp_expanded)

    v_profiles_np = v_profiles_masked.values  # Shape: (n_cases, vertical_levels)

    # Compute the mean profile (averaged over all cases)
    
    composite_profiles[time_label] = np.nanmean(v_profiles_np, axis=0)
    
    print(time_label, "complete")

v_dryapes_all_times = pd.DataFrame(composite_profiles)
# Out:
# 0lst complete
# 3lst complete
# 6lst complete
# 9lst complete
# 12lst complete
# 15lst complete
# 18lst complete
# 21lst complete

# %% [markdown]
# #### wet apes meridional wind speed

# %%
pressure_levels = _0lst['level'].data * 100 

xr_all_times = {
    
    "0lst": _0lst, "3lst": _3lst, "6lst": _6lst, "9lst": _9lst,
    
    "12lst": _12lst, "15lst": _15lst, "18lst": _18lst, "21lst": _21lst
}

wetapes['date'] = pd.to_datetime(wetapes['date'])

composite_profiles = {}

for time_label, ds in xr_all_times.items():
    
    v_profiles = ds.sel(
        
        time=xr.DataArray(wetapes['date'].values, dims="points"),
        
        latitude=xr.DataArray(wetapes['latitude'].values, dims="points"),
        
        longitude=xr.DataArray(wetapes['longitude'].values, dims="points"),
        
        method="nearest"
    
    )['v']
    
    sp_expanded = np.expand_dims(wetapes['average_sp'].values, axis=1)  # Shape (n_cases, 1)

    v_profiles_masked = v_profiles.where(pressure_levels < sp_expanded)

    v_profiles_np = v_profiles_masked.values  # Shape: (n_cases, vertical_levels)

    # Compute the mean profile (averaged over all cases)
    
    composite_profiles[time_label] = np.nanmean(v_profiles_np, axis=0)
    
    print(time_label, "complete")

v_wetapes_all_times = pd.DataFrame(composite_profiles)
# Out:
# 0lst complete
# 3lst complete
# 6lst complete
# 9lst complete
# 12lst complete
# 15lst complete
# 18lst complete
# 21lst complete

# %% [markdown]
# #### plot meridional wind speed

# %%
pressure = _0lst['level'].data  # Assuming this is consistent for both dry and wet cases

profile_columns = [col for col in v_dryapes_all_times.columns]

dry_color = "#4169E1"  # Royal Blue
wet_color = "#FF8C00"  # Dark Orange

num_profiles = len(profile_columns)

rows = 2
cols = min(4, num_profiles)  # Ensures no extra empty columns

fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 7), sharey=True)
axes = np.ravel(axes)  # Flatten in case of 2D array

# Define pressure levels to shade
shade_min = 800  # hPa

shade_max = 600  # hPa

# Loop through each column (each time of day) and plot dry and wet profiles
for i, (ax, col) in enumerate(zip(axes, profile_columns)):
    
    # Plot the dry and wet profiles
    ax.plot(v_dryapes_all_times[col] , pressure, label=f'Dry APEs', color=dry_color, linewidth=3)
    
    ax.plot(v_wetapes_all_times[col] , pressure, label=f'Wet APEs', color=wet_color, linewidth=3)
    
    # Shade the 800-600 hPa region
    ax.fill_betweenx(pressure, -10, 10, 
                     where=(pressure <= shade_min) & (pressure >= shade_max), 
                     color='gray', alpha=0.3)
    
    ax.invert_yaxis()  # Invert for atmospheric convention
    
    ax.set_xlim(-10, 10)  # Set x-axis limits
    
    ax.set_title(f'{col} Profile', fontsize=22)  # Title with hour label
    
    ax.set_xlabel('v (m/s)', fontsize=18)  # x-label
    
    ax.tick_params(axis='both', which='major', labelsize=18)  # Tick label size
    
    ax.axvline(x=0, color='black', linestyle='--', linewidth=1.5)  # Zero reference line
    
    ax.grid(True)
    
    # Add legend only to the first subplot
    if i == 0:
        
        ax.legend(fontsize=16, loc='best')

plt.tight_layout()

plt.gca().invert_yaxis()

plt.show()

# %% [markdown]
# #### dryapes zonal wind speed

# %%
pressure_levels = _0lst['level'].data * 100 

xr_all_times = {
    
    "0lst": _0lst, "3lst": _3lst, "6lst": _6lst, "9lst": _9lst,
    
    "12lst": _12lst, "15lst": _15lst, "18lst": _18lst, "21lst": _21lst
}

dryapes['date'] = pd.to_datetime(dryapes['date'])

composite_profiles = {}

for time_label, ds in xr_all_times.items():
    
    u_profiles = ds.sel(
        
        time=xr.DataArray(dryapes['date'].values, dims="points"),
        
        latitude=xr.DataArray(dryapes['latitude'].values, dims="points"),
        
        longitude=xr.DataArray(dryapes['longitude'].values, dims="points"),
        
        method="nearest"
    
    )['u']
    
    sp_expanded = np.expand_dims(dryapes['average_sp'].values, axis=1)  # Shape (n_cases, 1)

    u_profiles_masked = u_profiles.where(pressure_levels < sp_expanded)

    u_profiles_np = u_profiles_masked.values  # Shape: (n_cases, vertical_levels)

    # Compute the mean profile (averaged over all cases)
    
    composite_profiles[time_label] = np.nanmean(u_profiles_np, axis=0)
    
    print(time_label, "complete")

u_dryapes_all_times = pd.DataFrame(composite_profiles)
# Out:
# 0lst complete
# 3lst complete
# 6lst complete
# 9lst complete
# 12lst complete
# 15lst complete
# 18lst complete
# 21lst complete

# %% [markdown]
# #### wetapes zonal wind speed

# %%
pressure_levels = _0lst['level'].data * 100 

xr_all_times = {
    
    "0lst": _0lst, "3lst": _3lst, "6lst": _6lst, "9lst": _9lst,
    
    "12lst": _12lst, "15lst": _15lst, "18lst": _18lst, "21lst": _21lst
}

wetapes['date'] = pd.to_datetime(wetapes['date'])

composite_profiles = {}

for time_label, ds in xr_all_times.items():
    
    u_profiles = ds.sel(
        
        time=xr.DataArray(wetapes['date'].values, dims="points"),
        
        latitude=xr.DataArray(wetapes['latitude'].values, dims="points"),
        
        longitude=xr.DataArray(wetapes['longitude'].values, dims="points"),
        
        method="nearest"
    
    )['u']
    
    sp_expanded = np.expand_dims(wetapes['average_sp'].values, axis=1)  # Shape (n_cases, 1)

    u_profiles_masked = u_profiles.where(pressure_levels < sp_expanded)

    u_profiles_np = u_profiles_masked.values  # Shape: (n_cases, vertical_levels)

    # Compute the mean profile (averaged over all cases)
    
    composite_profiles[time_label] = np.nanmean(u_profiles_np, axis=0)
    
    print(time_label, "complete")

u_wetapes_all_times = pd.DataFrame(composite_profiles)
# Out:
# 0lst complete
# 3lst complete
# 6lst complete
# 9lst complete
# 12lst complete
# 15lst complete
# 18lst complete
# 21lst complete

# %% [markdown]
# #### plot zonal wind speeds

# %%
pressure = _0lst['level'].data  # Assuming this is consistent for both dry and wet cases

profile_columns = [col for col in v_dryapes_all_times.columns]

dry_color = "#4169E1"  # Royal Blue
wet_color = "#FF8C00"  # Dark Orange

num_profiles = len(profile_columns)

rows = 2
cols = min(4, num_profiles)  # Ensures no extra empty columns

fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 7), sharey=True)
axes = np.ravel(axes)  # Flatten in case of 2D array

# Define pressure levels to shade
shade_min = 800  # hPa

shade_max = 600  # hPa

# Loop through each column (each time of day) and plot dry and wet profiles
for i, (ax, col) in enumerate(zip(axes, profile_columns)):
    
    # Plot the dry and wet profiles
    ax.plot(u_dryapes_all_times[col] , pressure, label=f'Dry APEs', color=dry_color, linewidth=3)
    
    ax.plot(u_wetapes_all_times[col] , pressure, label=f'Wet APEs', color=wet_color, linewidth=3)
    
    # Shade the 800-600 hPa region
    ax.fill_betweenx(pressure, -20, 20, 
                     where=(pressure <= shade_min) & (pressure >= shade_max), 
                     color='gray', alpha=0.3)
    
    ax.invert_yaxis()  # Invert for atmospheric convention
    
    ax.set_xlim(-20, 20)  # Set x-axis limits
    
    ax.set_title(f'{col} Profile', fontsize=22)  # Title with hour label
    
    ax.set_xlabel('u (m/s)', fontsize=18)  # x-label
    
    ax.tick_params(axis='both', which='major', labelsize=18)  # Tick label size
    
    ax.axvline(x=0, color='black', linestyle='--', linewidth=1.5)  # Zero reference line
    
    ax.grid(True)
    
    # Add legend only to the first subplot
    if i == 0:
        
        ax.legend(fontsize=16, loc='best')

plt.tight_layout()

plt.gca().invert_yaxis()

plt.show()

# %%
# w_filtered = xr_dryapes['w']

# w_hourly_mean = w_filtered.groupby("time.hour").mean(dim="time")

# %%
# for analyzing how western versus eastern half vertical velocity changes over time

# w = uvwq_sgp['w']  # Shape: (time, level, lat, lon)

# # Define latitude and longitude bounds

# lat_bounds = (39, 30)

# west = (-105, -100)

# east = (-100, -95)

# # Subset the data for both regions
# w_west = w.sel(longitude=slice(*west), latitude=slice(*lat_bounds)).mean(dim=['longitude', 'latitude'])

# w_east = w.sel(longitude=slice(*east), latitude=slice(*lat_bounds)).mean(dim=['longitude', 'latitude'])

# w_west = w_west.groupby('time.hour').mean(dim='time')

# w_east = w_east.groupby('time.hour').mean(dim='time')

# # Ensure pressure_levels is a NumPy array
# pressure_levels = w_west.level.values  # Convert to NumPy array

# # Ensure w_west and w_east are now NumPy arrays
# w_west = w_west.load().data  # Shape: (24, num_levels)

# w_east = w_east.load().data  # Shape: (24, num_levels)

# print("loaded!")

# Define the actual hour labels corresponding to indices 0-7
# hour_labels = [0, 3, 6, 9, 12, 15, 18, 21]  

# # Create a 2x4 subplot layout
# fig, axes = plt.subplots(2, 4, figsize=(12, 8), sharey=True, sharex=True)

# # Flatten the axes array for easier indexing
# axes = axes.flatten()

# # Loop through each hour index and create the plots
# for i in range(8):  
#     hour = hour_labels[i]  # Map index to actual hour
#     ax = axes[i]  # Select subplot
    
#     # Plot west and east profiles
#     ax.plot(w_west[i, :]/100, pressure_levels, label="West (-105° to -100°)", color="blue")
#     ax.plot(w_east[i, :]/100, pressure_levels, label="East (-100° to -95°)", color="red")
    
#     # Formatting
#     ax.set_title(f'{hour:02d}Z', fontsize=10)
#     ax.axvline(0, color='black', linestyle='--', linewidth=1)  # Reference line at 0
#     ax.invert_yaxis()  # Pressure increases downward
    
#     if i % 4 == 0:  # Label y-axis only on the leftmost plots
#         ax.set_ylabel('Pressure (hPa)')
    
#     if i >= 4:  # Label x-axis only on the bottom row
#         ax.set_xlabel('Vertical Velocity (-hPa/s)')
#         plt.setp(ax.get_xticklabels(), rotation=45, ha="right")  # Rotate x-axis labels

# # Add a legend to one of the plots (top-left)
# axes[0].legend(loc='upper right', fontsize=8)

# plt.tight_layout()
# plt.gca().invert_yaxis()
# plt.show()

# %%
# ## loading u, v, w and q for 0lst

# _0lst_u = _0lst['u'].load().data

# print("u loaded")

# _0lst_v = _0lst['v'].load().data

# print("v loaded")

# _0lst_w = _0lst['w'].load().data

# print("w loaded")

# _0lst_q = _0lst['q'].load().data

# print("q loaded")

# %%
# ## loading u, v, w and q for 6lst

# _6lst_u = _6lst['u'].load().data

# print("u loaded")

# _6lst_v = _6lst['v'].load().data

# print("v loaded")

# _6lst_w = _6lst['w'].load().data

# print("w loaded")

# _6lst_q = _6lst['q'].load().data

# print("q loaded")

# %%
# ## loading u, v, w and q for 12lst

# _12lst_u = _12lst['u'].load().data

# print("u loaded")

# _12lst_v = _12lst['v'].load().data

# print("v loaded")

# _12lst_w = _12lst['w'].load().data

# print("w loaded")

# _12lst_q = _12lst['q'].load().data

# print("q loaded")

# %%
# times = _0lst['time'].data

# latitude = _0lst['latitude'].data

# longitude = _0lst['longitude'].data

# pressure = _0lst['level'].data

# %% [markdown]
# ### calculating average u, v, w, and q profiles for 0 LST, appending to master

# %%
# master['0lst_u_profile'] = None

# master['0lst_v_profile'] = None

# master['0lst_w_profile'] = None

# master['0lst_q_profile'] = None

# for date in range(master.shape[0]):
        
#     target_date = master['date'].iloc[date]  
    
#     target_date = np.datetime64(target_date)

#     # Find the index in daily_avg['time'].data
    
#     date_idx = np.where(_0lst['time'].data == target_date)[0][0]

#     lat_idx = master['latitude'].iloc[date]
    
#     lon_idx = master['longitude'].iloc[date]

#     # Define the center point and half-window (in degrees)
    
#     delta = 0.5
    
#     lat_mask = (latitude >= (lat_idx - delta)) & (latitude <= (lat_idx + delta))
    
#     lon_mask = (longitude >= (lon_idx - delta)) & (longitude <= (lon_idx + delta))

#     lat_indices = np.where(lat_mask)[0]
    
#     lon_indices = np.where(lon_mask)[0]

#     lat_mini = latitude[lat_indices]
    
#     lon_mini = longitude[lon_indices]

#     # Extract mini domains for u, v, q, w
    
#     u = _0lst_u
    
#     v = _0lst_v
    
#     w = _0lst_w
    
#     q = _0lst_q 
    
#     u_mini = u[date_idx, :, :, :][:, lat_mask, :][:, :, lon_mask]
    
#     v_mini = v[date_idx, :, :, :][:, lat_mask, :][:, :, lon_mask]
    
#     w_mini = w[date_idx, :, :, :][:, lat_mask, :][:, :, lon_mask]

#     q_mini = q[date_idx, :, :, :][:, lat_mask, :][:, :, lon_mask]
        
#     # Compute average profiles
    
#     mean_u_profile = np.nanmean(u_mini, axis=(1, 2))  # Averaging over lat and lon
        
#     mean_v_profile = np.nanmean(v_mini, axis=(1, 2))  # Averaging over lat and lon
    
#     mean_w_profile = np.nanmean(w_mini, axis=(1, 2))  # Averaging over lat and lon

#     mean_q_profile = np.nanmean(q_mini, axis=(1, 2)) # Averaging over lat and lon
        
#     # Assign results to the DataFrame
    
#     master.at[date, '0lst_u_profile'] = mean_u_profile
        
#     master.at[date, '0lst_v_profile'] = mean_v_profile
            
#     master.at[date, '0lst_w_profile'] = mean_w_profile
    
#     master.at[date, '0lst_q_profile'] = mean_q_profile

# %% [markdown]
# ### calculating average u, v, w, and q profiles for 6 LST, appending to master

# %%
# master['6lst_u_profile'] = None

# master['6lst_v_profile'] = None

# master['6lst_w_profile'] = None

# master['6lst_q_profile'] = None

# for date in range(master.shape[0]):
        
#     target_date = master['date'].iloc[date]  
    
#     target_date = np.datetime64(target_date)

#     # Find the index in daily_avg['time'].data
    
#     date_idx = np.where(_0lst['time'].data == target_date)[0][0]

#     lat_idx = master['latitude'].iloc[date]
    
#     lon_idx = master['longitude'].iloc[date]

#     # Define the center point and half-window (in degrees)
    
#     delta = 0.5
    
#     lat_mask = (latitude >= (lat_idx - delta)) & (latitude <= (lat_idx + delta))
    
#     lon_mask = (longitude >= (lon_idx - delta)) & (longitude <= (lon_idx + delta))

#     lat_indices = np.where(lat_mask)[0]
    
#     lon_indices = np.where(lon_mask)[0]

#     lat_mini = latitude[lat_indices]
    
#     lon_mini = longitude[lon_indices]

#     # Extract mini domains for u, v, q, w
    
#     u = _6lst_u
    
#     v = _6lst_v
    
#     w = _6lst_w
    
#     q = _6lst_q 
    
#     u_mini = u[date_idx, :, :, :][:, lat_mask, :][:, :, lon_mask]
    
#     v_mini = v[date_idx, :, :, :][:, lat_mask, :][:, :, lon_mask]
    
#     w_mini = w[date_idx, :, :, :][:, lat_mask, :][:, :, lon_mask]

#     q_mini = q[date_idx, :, :, :][:, lat_mask, :][:, :, lon_mask]
        
#     # Compute average profiles
    
#     mean_u_profile = np.nanmean(u_mini, axis=(1, 2))  # Averaging over lat and lon
        
#     mean_v_profile = np.nanmean(v_mini, axis=(1, 2))  # Averaging over lat and lon
    
#     mean_w_profile = np.nanmean(w_mini, axis=(1, 2))  # Averaging over lat and lon

#     mean_q_profile = np.nanmean(q_mini, axis=(1, 2)) # Averaging over lat and lon
        
#     # Assign results to the DataFrame
    
#     master.at[date, '6lst_u_profile'] = mean_u_profile
        
#     master.at[date, '6lst_v_profile'] = mean_v_profile
            
#     master.at[date, '6lst_w_profile'] = mean_w_profile
    
#     master.at[date, '6lst_q_profile'] = mean_q_profile

# %% [markdown]
# ### calculating average u, v, w, and q profiles for 12 LST, appending to master

# %%
# master['12lst_u_profile'] = None

# master['12lst_v_profile'] = None

# master['12lst_w_profile'] = None

# master['12lst_q_profile'] = None

# for date in range(master.shape[0]):
        
#     target_date = master['date'].iloc[date]  
    
#     target_date = np.datetime64(target_date)

#     # Find the index in daily_avg['time'].data
    
#     date_idx = np.where(_0lst['time'].data == target_date)[0][0]

#     lat_idx = master['latitude'].iloc[date]
    
#     lon_idx = master['longitude'].iloc[date]

#     # Define the center point and half-window (in degrees)
    
#     delta = 0.5
    
#     lat_mask = (latitude >= (lat_idx - delta)) & (latitude <= (lat_idx + delta))
    
#     lon_mask = (longitude >= (lon_idx - delta)) & (longitude <= (lon_idx + delta))

#     lat_indices = np.where(lat_mask)[0]
    
#     lon_indices = np.where(lon_mask)[0]

#     lat_mini = latitude[lat_indices]
    
#     lon_mini = longitude[lon_indices]

#     # Extract mini domains for u, v, q, w
    
#     u = _12lst_u
    
#     v = _12lst_v
    
#     w = _12lst_w
    
#     q = _12lst_q 
    
#     u_mini = u[date_idx, :, :, :][:, lat_mask, :][:, :, lon_mask]
    
#     v_mini = v[date_idx, :, :, :][:, lat_mask, :][:, :, lon_mask]
    
#     w_mini = w[date_idx, :, :, :][:, lat_mask, :][:, :, lon_mask]

#     q_mini = q[date_idx, :, :, :][:, lat_mask, :][:, :, lon_mask]
        
#     # Compute average profiles
    
#     mean_u_profile = np.nanmean(u_mini, axis=(1, 2))  # Averaging over lat and lon
        
#     mean_v_profile = np.nanmean(v_mini, axis=(1, 2))  # Averaging over lat and lon
    
#     mean_w_profile = np.nanmean(w_mini, axis=(1, 2))  # Averaging over lat and lon

#     mean_q_profile = np.nanmean(q_mini, axis=(1, 2)) # Averaging over lat and lon
        
#     # Assign results to the DataFrame
    
#     master.at[date, '12lst_u_profile'] = mean_u_profile
        
#     master.at[date, '12lst_v_profile'] = mean_v_profile
            
#     master.at[date, '12lst_w_profile'] = mean_w_profile
    
#     master.at[date, '12lst_q_profile'] = mean_q_profile

# %%
# # accounting for surface pressure so that we don't include below ground values

# columns_to_mask = [
#     "0lst_u_profile", "0lst_v_profile", "0lst_w_profile", "0lst_q_profile",
#     "6lst_u_profile", "6lst_v_profile", "6lst_w_profile", "6lst_q_profile",
#     "12lst_u_profile", "12lst_v_profile", "12lst_w_profile", "12lst_q_profile"
# ]

# def mask_profiles(row):
    
#     underground_mask = pressure > row['average_sp']  
    
#     for col in columns_to_mask:
        
#         row[col] = np.where(underground_mask, np.nan, row[col])
    
#     return row

# master_clean = master.apply(mask_profiles, axis=1)

# %%
# # define dryapes and wetapes once all 0, 6, and 12 LST profiles have been created

# dryapes = master_clean[master_clean['dryape']==True]

# wetapes = master_clean[master_clean['wetape']==True]

# print("complete!")

# %% [markdown]
# ### Plot composite wind and humidity profiles

# %%
# def plot_mfc_profiles(time_label, dryapes, wetapes, pressure):
#     """
#     Plots zonal & meridional wind speeds, vertical velocity, and specific humidity differences
#     for Dry and Wet APEs at the specified time label.

#     Parameters:
#         time_label (str): Time label ('0lst', '6lst', or '12lst')
#         dryapes (DataFrame): Dry APEs data containing wind, velocity, and humidity profiles
#         wetapes (DataFrame): Wet APEs data containing wind, velocity, and humidity profiles
#         pressure (array): Pressure levels for y-axis
#     """

#     # Compute mean and confidence intervals for all variables
#     dry_mean_zonal, dry_ci_zonal = compute_stats(dryapes[f'{time_label}_u_profile'].tolist())
#     dry_mean_merid, dry_ci_merid = compute_stats(dryapes[f'{time_label}_v_profile'].tolist())
#     dry_mean_vertical, dry_ci_vertical = compute_stats(dryapes[f'{time_label}_w_profile'].tolist())
#     dry_mean_vertical /= 100  # Convert units
#     dry_ci_vertical /= 100  # Convert CI
#     dry_mean_q, dry_ci_q = compute_stats(dryapes[f'{time_label}_q_profile'].tolist())

#     wet_mean_zonal, wet_ci_zonal = compute_stats(wetapes[f'{time_label}_u_profile'].tolist())
#     wet_mean_merid, wet_ci_merid = compute_stats(wetapes[f'{time_label}_v_profile'].tolist())
#     wet_mean_vertical, wet_ci_vertical = compute_stats(wetapes[f'{time_label}_w_profile'].tolist())
#     wet_mean_vertical /= 100  # Convert units
#     wet_ci_vertical /= 100  # Convert CI
#     wet_mean_q, wet_ci_q = compute_stats(wetapes[f'{time_label}_q_profile'].tolist())

#     # Convert specific humidity from kg/kg to g/kg
#     dry_mean_q_gkg = dry_mean_q * 1000
#     dry_ci_q_gkg = dry_ci_q * 1000
#     wet_mean_q_gkg = wet_mean_q * 1000
#     wet_ci_q_gkg = wet_ci_q * 1000

#     # Set fixed x-axis limits for consistency
#     xlimit_horizontal = (-16, 16)
#     xlimit_vertical = (-0.0007, 0.0007)
#     xlimit_q = (0, 15)

#     # Create a 1-row, 3-column figure layout
#     fig, axes = plt.subplots(1, 3, figsize=(24, 10), sharey=True)

#     ## **Figure 1: Zonal & Meridional Wind Speeds**
#     ax1 = axes[0]

#     # Plot Zonal Wind (u)
#     ax1.plot(dry_mean_zonal, pressure, label='Dry APEs Zonal (u)', linewidth=2, color='blue', linestyle='-')
#     ax1.fill_betweenx(pressure, dry_mean_zonal - dry_ci_zonal, dry_mean_zonal + dry_ci_zonal, color='blue', alpha=0.3)

#     ax1.plot(wet_mean_zonal, pressure, label='Wet APEs Zonal (u)', linewidth=2, color='blue', linestyle='--')
#     ax1.fill_betweenx(pressure, wet_mean_zonal - wet_ci_zonal, wet_mean_zonal + wet_ci_zonal, color='blue', alpha=0.3)

#     # Plot Meridional Wind (v)
#     ax1.plot(dry_mean_merid, pressure, label='Dry APEs Meridional (v)', linewidth=2, color='green', linestyle='-')
#     ax1.fill_betweenx(pressure, dry_mean_merid - dry_ci_merid, dry_mean_merid + dry_ci_merid, color='green', alpha=0.3)

#     ax1.plot(wet_mean_merid, pressure, label='Wet APEs Meridional (v)', linewidth=2, color='green', linestyle='--')
#     ax1.fill_betweenx(pressure, wet_mean_merid - wet_ci_merid, wet_mean_merid + wet_ci_merid, color='green', alpha=0.3)

#     # Formatting
#     ax1.set_xlim(xlimit_horizontal)
#     ax1.axvline(x=0, color='black', linestyle='--', linewidth=1.5)
#     ax1.set_xlabel('Wind Speed (m/s)', fontsize=18)
#     ax1.set_title(f'Zonal & Meridional Wind Speeds ({time_label.upper()})', fontsize=20, fontweight='bold')
#     ax1.grid(True, linestyle='--', alpha=0.6)
#     ax1.legend(fontsize=14)
#     ax1.tick_params(axis='both', labelsize=18)

#     ## **Figure 2: Vertical Velocity**
#     ax2 = axes[1]

#     # Plot Vertical Velocity (w)
#     ax2.plot(dry_mean_vertical, pressure, label='Dry APEs', linewidth=2, color='red', linestyle='-')
#     ax2.fill_betweenx(pressure, dry_mean_vertical - dry_ci_vertical, dry_mean_vertical + dry_ci_vertical, color='red', alpha=0.3)

#     ax2.plot(wet_mean_vertical, pressure, label='Wet APEs', linewidth=2, color='red', linestyle='--')
#     ax2.fill_betweenx(pressure, wet_mean_vertical - wet_ci_vertical, wet_mean_vertical + wet_ci_vertical, color='red', alpha=0.3)

#     # Formatting
#     ax2.set_xlim(xlimit_vertical)
#     ax2.axvline(x=0, color='black', linestyle='--', linewidth=1.5)
#     ax2.set_xlabel(r'Vertical Velocity (-hPa/s)', fontsize=18)
#     ax2.set_title(f'Vertical Velocity ({time_label.upper()})', fontsize=20, fontweight='bold')
#     ax2.grid(True, linestyle='--', alpha=0.6)
#     ax2.legend(fontsize=14)
#     ax2.tick_params(axis='both', labelsize=18, rotation=45)

#     ## **Figure 3: Specific Humidity**
#     ax3 = axes[2]

#     # Plot Specific Humidity (q)
#     ax3.plot(dry_mean_q_gkg, pressure, label='Dry APEs', linewidth=2, color='purple', linestyle='-')
#     ax3.fill_betweenx(pressure, dry_mean_q_gkg - dry_ci_q_gkg, dry_mean_q_gkg + dry_ci_q_gkg, color='purple', alpha=0.3)

#     ax3.plot(wet_mean_q_gkg, pressure, label='Wet APEs', linewidth=2, color='purple', linestyle='--')
#     ax3.fill_betweenx(pressure, wet_mean_q_gkg - wet_ci_q_gkg, wet_mean_q_gkg + wet_ci_q_gkg, color='purple', alpha=0.3)

#     # Formatting
#     ax3.set_xlim(xlimit_q)
#     ax3.set_xlabel(r'Specific Humidity (g/kg)', fontsize=18)
#     ax3.set_title(f'Specific Humidity ({time_label.upper()})', fontsize=20, fontweight='bold')
#     ax3.grid(True, linestyle='--', alpha=0.6)
#     ax3.legend(fontsize=14)
#     ax3.tick_params(axis='both', labelsize=18)

#     ## **Overall Figure Formatting**
#     fig.text(0.04, 0.5, 'Pressure (hPa)', va='center', rotation='vertical', fontsize=18, fontweight='bold')
#     plt.gca().invert_yaxis()
#     plt.tight_layout(rect=[0.05, 0.03, 1, 0.95])

#     plt.show()


# # **Plot for all three time steps dynamically**
# for time_label in ["0lst", "6lst", "12lst"]:
#     plot_mfc_profiles(time_label, dryapes, wetapes, pressure)

# %%
# def plot_dry_apes_specific_humidity(dryapes, pressure):
#     """
#     Plots specific humidity profiles for Dry APEs at all times (0 LST, 6 LST, 12 LST) on one figure.

#     Parameters:
#         dryapes (DataFrame): Dry APEs data containing specific humidity profiles at different times.
#         pressure (array): Pressure levels for y-axis.
#     """

#     time_labels = ["0lst", "6lst", "12lst"]
#     colors = ["blue", "green", "purple"]  # Different colors for each time
#     linestyles = ["-", "--", ":"]  # Different line styles for better distinction

#     # Create figure
#     fig, ax = plt.subplots(figsize=(8, 6))

#     for time_label, color, linestyle in zip(time_labels, colors, linestyles):
#         # Convert specific humidity to g/kg
#         dry_mean_q, dry_ci_q = compute_stats(dryapes[f'{time_label}_q_profile'].tolist())
#         dry_mean_q_gkg = dry_mean_q * 1000
#         dry_ci_q_gkg = dry_ci_q * 1000

#         # Plot the mean profile with shaded confidence interval
#         ax.plot(dry_mean_q_gkg, pressure, label=f"Dry APEs {time_label.upper()}", linewidth=2, color=color, linestyle=linestyle)
#         ax.fill_betweenx(pressure, dry_mean_q_gkg - dry_ci_q_gkg, dry_mean_q_gkg + dry_ci_q_gkg, color=color, alpha=0.2)

#     # Formatting
#     ax.set_xlim(0, 15)  # Set x-axis limits for specific humidity (g/kg)
#     ax.set_xlabel(r'Specific Humidity (g/kg)', fontsize=18)
#     ax.set_ylabel('Pressure (hPa)', fontsize=18)
#     ax.set_title('Specific Humidity Profiles for Dry APEs', fontsize=20, fontweight='bold')
#     ax.grid(True, linestyle='--', alpha=0.6)
#     ax.legend(fontsize=14)
#     ax.tick_params(axis='both', labelsize=16)

#     # Invert y-axis to have pressure decreasing upwards
#     ax.invert_yaxis()
    
#     plt.ylim(850, 600)
    
#     plt.xlim(3, 10)

#     plt.show()

# # **Call function to plot specific humidity for Dry APEs**
# plot_dry_apes_specific_humidity(dryapes, pressure)

# %%
# def plot_mfc_differences(time_label, dryapes, wetapes, pressure):
#     """
#     Plots differences between Dry and Wet APEs for zonal & meridional wind speeds, vertical velocity,
#     and specific humidity at the specified time label.

#     Parameters:
#         time_label (str): Time label ('0lst', '6lst', or '12lst')
#         dryapes (DataFrame): Dry APEs data containing wind, velocity, and humidity profiles
#         wetapes (DataFrame): Wet APEs data containing wind, velocity, and humidity profiles
#         pressure (array): Pressure levels for y-axis
#     """

#     dry_u_profile = np.vstack(dryapes[f'{time_label}_u_profile'])
#     wet_u_profile = np.vstack(wetapes[f'{time_label}_u_profile'])

#     dry_v_profile = np.vstack(dryapes[f'{time_label}_v_profile'])
#     wet_v_profile = np.vstack(wetapes[f'{time_label}_v_profile'])

#     dry_w_profile = np.vstack(dryapes[f'{time_label}_w_profile']) / 100  # Convert units
#     wet_w_profile = np.vstack(wetapes[f'{time_label}_w_profile']) / 100  # Convert units

#     dry_q_profile = np.vstack(dryapes[f'{time_label}_q_profile'])
#     wet_q_profile = np.vstack(wetapes[f'{time_label}_q_profile'])

#     # Compute Differences
#     diff_mean_zonal = np.nanmean(dry_u_profile, axis=0) - np.nanmean(wet_u_profile, axis=0)

#     diff_mean_merid = np.nanmean(dry_v_profile, axis=0) - np.nanmean(wet_v_profile, axis=0)

#     diff_mean_vertical = np.nanmean(dry_w_profile, axis=0) - np.nanmean(wet_w_profile, axis=0)

#     diff_mean_q_gkg = (np.nanmean(dry_q_profile, axis=0) - np.nanmean(wet_q_profile, axis=0)) * 1000

#     # Set fixed x-axis limits for consistency
#     xlimit_horizontal = (-10, 10)
#     xlimit_vertical = (-0.001, 0.001)
#     xlimit_q = (-5, 1)

#     # Create a 1-row, 3-column figure layout
#     fig, axes = plt.subplots(1, 3, figsize=(24, 10), sharey=True)

#     ## **Figure 1: Zonal & Meridional Wind Differences**
#     ax1 = axes[0]

#     # Plot Zonal Wind Difference
#     ax1.plot(diff_mean_zonal, pressure, label='Zonal Wind (u)', linewidth=2, color='blue')
# #     ax1.fill_betweenx(pressure, diff_mean_zonal - diff_ci_zonal, diff_mean_zonal + diff_ci_zonal, color='blue', alpha=0.3)

#     # Plot Meridional Wind Difference
#     ax1.plot(diff_mean_merid, pressure, label='Meridional Wind (v)', linewidth=2, color='green')
# #     ax1.fill_betweenx(pressure, diff_mean_merid - diff_ci_merid, diff_mean_merid + diff_ci_merid, color='green', alpha=0.3)

#     # Formatting
#     ax1.set_xlim(xlimit_horizontal)
#     ax1.axvline(x=0, color='black', linestyle='--', linewidth=1.5)
#     ax1.set_xlabel('Wind Speed Difference (m/s)', fontsize=18)
#     ax1.set_title(f'Zonal & Meridional Wind Differences ({time_label.upper()})', fontsize=20, fontweight='bold')
#     ax1.grid(True, linestyle='--', alpha=0.6)
#     ax1.legend(fontsize=14)
#     ax1.tick_params(axis='both', labelsize=18)

#     ## **Figure 2: Vertical Velocity Differences**
#     ax2 = axes[1]

#     # Plot Vertical Velocity Difference
#     ax2.plot(diff_mean_vertical, pressure, linewidth=2, color='red')
# #     ax2.fill_betweenx(pressure, diff_mean_vertical - diff_ci_vertical, diff_mean_vertical + diff_ci_vertical, color='red', alpha=0.3)

#     # Formatting
#     ax2.set_xlim(xlimit_vertical)
#     ax2.axvline(x=0, color='black', linestyle='--', linewidth=1.5)
#     ax2.set_xlabel(r'Vertical Velocity Difference (-hPa/s)', fontsize=18)
#     ax2.set_title(f'Vertical Velocity Differences ({time_label.upper()})', fontsize=20, fontweight='bold')
#     ax2.grid(True, linestyle='--', alpha=0.6)
#     ax2.tick_params(axis='both', labelsize=18, rotation=45)

#     ## **Figure 3: Specific Humidity Differences**
#     ax3 = axes[2]

#     # Plot Specific Humidity Difference
#     ax3.plot(diff_mean_q_gkg, pressure, linewidth=2, color='purple')
# #     ax3.fill_betweenx(pressure, diff_mean_q_gkg - diff_ci_q_gkg, diff_mean_q_gkg + diff_ci_q_gkg, color='purple', alpha=0.3)

#     ax3.set_xlim(xlimit_q)

#     # Formatting
#     ax3.axvline(x=0, color='black', linestyle='--', linewidth=1.5)
#     ax3.set_xlabel(r'Specific Humidity Difference (g/kg)', fontsize=18)
#     ax3.set_title(f'Specific Humidity Differences ({time_label.upper()})', fontsize=20, fontweight='bold')
#     ax3.grid(True, linestyle='--', alpha=0.6)
#     ax3.tick_params(axis='both', labelsize=18)

#     ## **Overall Figure Formatting**
#     fig.text(0.04, 0.5, 'Pressure (hPa)', va='center', rotation='vertical', fontsize=18, fontweight='bold')
#     plt.gca().invert_yaxis()
#     plt.tight_layout(rect=[0.05, 0.03, 1, 0.95])

#     plt.show()


# # **Plot for all three time steps dynamically**
# for time_label in ["0lst", "6lst", "12lst"]:
#     plot_mfc_differences(time_label, dryapes, wetapes, pressure)
